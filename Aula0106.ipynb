# %%
pessoa1 = {'Nome': 'Daniel', 'Idade': 29, 'Cursos': ['Lógica de Programação', 'Python Básico', 'Python Intermediário', 'Html']}

print(pessoa1)

verduras = {'alface': 7.99, 'batata': 3.99, 'tomate': 17.99, 'feijão': 5.99}
print(f'O valor do Tomate é R${verduras['tomate']}')

print(dir(verduras))

#print(verduras['Manga'])

print('Manga' in verduras)
print('Manga' not in verduras)
print(verduras.keys())
print(verduras.values())

while True:
  produto = input("Digite o nome do produto ou fim para terminar: ").lower()
  if produto == 'fim':
    break
  if produto in verduras:
    print(f'O preço do {produto} é R${verduras[produto]:5.2f}')
  else:
    print('Produto não encontrado!')
# Out:
# {'Nome': 'Daniel', 'Idade': 29, 'Cursos': ['Lógica de Programação', 'Python Básico', 'Python Intermediário', 'Html']}
# O valor do Tomate é R$17.99
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
# False
# True
# dict_keys(['alface', 'batata', 'tomate', 'feijão'])
# dict_values([7.99, 3.99, 17.99, 5.99])
# Digite o nome do produto ou fim para terminar: tomate
# O preço do tomate é R$17.99
# Digite o nome do produto ou fim para terminar: alface
# ...

# %%
tupla = tuple()
tupla = ()
print(type(tupla))
print(dir(tupla))

tupla = ('Um')*3
print(type(tupla))

tupla = ('Um' ,)
print(id(tupla))

tupla = ('Dois', 'Tres')
print(id(tupla))
#tupla[1] = 'dois

print(tupla[0])
#tupla[0] = 'Daniel'
print(tupla[0])

cores = ('Preto', 'Roxo', 'Vermelho', 'Branco', 'Azul', 'Azul', 'Azul')

print(cores[0])
print(cores[1])
