# %%
#2.1
conta = 10 + 20 * 30
print(conta)
conta2 = (4 ** 2) / 30
print(conta2)
conta3 = (9 ** 4 + 2) * 6 - 1
print(conta3)

# %%
#Programa 2.2
salario = 1500
aumento = 5
print(salario + (salario * aumento / 100))
# Out:
# 1575.0

# %%
#Programa 2.3
print(1500 + (1500 * 5 / 100))
# Out:
# 1575.0

# %%
#2.3
nome = 'Francisco Martins'
print(nome)

# %%
#2.4
a = 3
b = 5

resultado = (2 * a) * (3 * b)

print(resultado)
# Out:
# 90

# %%
#2.5
a = 4
b = 8
c = 7
print(f'O resultado da soma dos números é: {a + b + c}')
# Out:
# O resultado da soma dos números é: 19

# %%
#2.6
salario = 750
aumento = 15

print(salario + (salario * aumento / 100))
# Out:
# 862.5
